# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import torch
import sys
sys.path.append('../src')

# %%
import segmentation_models_pytorch as smp
from utils import fetch_log
# Out:
# /esat/gebo/mli1/conda3/envs/geoinf/lib/python3.8/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn(

# %%
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='mit_b0',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='mit_b2',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='mit_b5',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
# _, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='timm-mobilenetv3_small_minimal',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='vgg11_bn',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='vgg16_bn',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='vgg19_bn',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
# _, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='timm-regnety_160',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='timm-regnety_320',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
# Out:
# parameters count of Unet_mit_b0 is 5551374
# parameters count of Unet_mit_b2 is 27478894
# parameters count of Unet_mit_b5 is 84725614
# parameters count of Unet_vgg11_bn is 18261422
# parameters count of Unet_vgg16_bn is 23758574
# parameters count of Unet_vgg19_bn is 29070830
# parameters count of Unet_timm-regnety_320 is 155219384

# %%
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='mit_b0',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='mit_b2',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='mit_b5',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
# _, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='timm-mobilenetv3_small_minimal',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='vgg11_bn',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='vgg16_bn',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='vgg19_bn',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
# _, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='timm-regnety_160',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='acc',log_log=False)
_, _, fig1 = fetch_log.fetch_log(arch='Unet',encoder='timm-regnety_320',pretrained='imagenet',batch_number=100,batch_size=8,acc_or_loss='loss',log_log=True)
# Out:
# parameters count of Unet_mit_b0 is 5551374
# /esat/gebo/mli1/conda3/envs/geoinf/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# parameters count of Unet_mit_b2 is 27478894
# /esat/gebo/mli1/conda3/envs/geoinf/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# parameters count of Unet_mit_b5 is 84725614
# /esat/gebo/mli1/conda3/envs/geoinf/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# parameters count of Unet_vgg11_bn is 18261422
# /esat/gebo/mli1/conda3/envs/geoinf/lib/python3.8/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ...

# %%
fig1.savefig('unet_5m24m85m155m_loss_log.png', dpi=2000, bbox_inches='tight')
